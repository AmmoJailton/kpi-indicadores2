# %%
IMessageContent = {
  'documento': 'relatorio 0641 friburgo shopping',
  'pages': [IPagecontent]
}

IPageContent[
  {
    'content': {
      'title': 'kpis loja mmartan fribugo shopping center',
      'tables': [dataframe]
    },
  },
  
  
  {
    'content': {
      'title': 'kpis vendedor mes',
      'tables': [dataframe, figura]
    },
    
    'content': {
      'title': 'kpis vendedor dia',
      'tables': [dataframe]
    },
  }
]

content: IPDFContent


class abstrata():
  def __init__(self):
    pass
  
  def generate_report(self, messageContent: IMessageContent) -> Message:
    return Message
  
  def formatar_para_aglguma_coisa(self, messageContent: IMessageContent) -> Message:
    return Message
  
  
  
class abstrataEnviar():
  def __init__(self):
    pass
  
  def send_report(self,) -> Message :
    return Message
  
  
  
class enviarEmail(abstrataEnviar):
  def send_report(self, **kwargs):
    if(self._checar_Email_existe == TRUE) :


class enviarSMS(abstrataEnviar):
  def send_report(self):
    
    return telefone
  
  def_cheacar_telefone_existe()
    
    
class enviarZap(abstrataEnviar):
  def send_report(self, **kwargs):
    telefone e seila mais o que
    
  

class geraPDF(abstrata):
  
  def generate_report(self, messageContent: IMessageContent) -> Message :
    # baseDeDados = self.getBase()
    
    filename = messageContent.documento + ".pdf"
    createdPages = []
    
    for page in messageContent.pages:
      pagina = self.criarPagina(page.content.title, page.content.tables)
      createdPages.append(pagina)
    
    return {filename, createdPages}
  
  
  # def send_report(self, info_de_quem_vai_receber_o_report: [string], mensagem_a_ser_enviada: [IMessageContent]) -> None:
  #   for email in info_de_quem_vai_receber_o_report:
  #     self.send_pdf_report(email, mensagem_a_ser_enviada)
      
      
/reportdiario

body {
  message_source: 'email' | 'sms' | 'fax'
}

df = funcão__pega_dados() # return IMessageContent
regionais = quem_vai_receber_o_report() [emails?, telefone]

message_source = {
  'email': enviarEmail.send_report,
  'sms': enviarSMS.send_report,
}

message_source[body_value]

mensagemPDF = geraPDF().generate_report(data=df, source='email')
mensagemSMS = geraSMS.generate_report(df)
mensagemZAp = geraSMS.generate_report(df)
email = enviarSMS().send_report()

message_source ={
  'email': enviarEmail.send_report,
  'sms': enviarSMS.send_report,
}

/report por hora
df


# class geraUatiZap(abstrata):
#   def generate_report(self, messageContent: IMessageContent) -> Message :
#     baseDeDados = self.getBasedosZapZap()
#     formatedDocumentto = self.generate_zap_message(messageContent, baseDeDados)
#     return formatedDocumentto asType Message
  
#   def send_report(self, info_de_quem_vai_receber_o_report: [string], mensagem_a_ser_enviada: [IMessageContent]) -> None:
#     for telefone in info_de_quem_vai_receber_o_report:
#       self.send_zap_message(telefone, mensagem_a_ser_enviada)
