# %% [markdown]
# # Imports

# %%
from commom.database.queries.query_instagram_monitor import QUERY_INSTAGRAM_MONITOR
from commom.database.queries.query_instagram_posts import QUERY_INSTAGRAM_POSTS
from commom.instagram_data.instagram_data_manager import InstagramDataManager
from commom.instagram_data.instagram_data_formater import InstagramDataFormater
from commom.database.data_handler import DataHandler
import pandas as pd
import datetime
import pickle
import requests
import os

# %% [markdown]
# # Instancias

# %%
data_handler = DataHandler()
data_manager = InstagramDataManager()

# %% [markdown]
# # Carregando Base

# %%
# BQ
# df_original = data_handler.read_from_bigquery(query=QUERY_INSTAGRAM_POSTS)
# df_original = data_handler.read_from_bigquery(query=QUERY_INSTAGRAM_MONITOR)

#Local
# df_original = pd.read_pickle('df_original.pkl')
# df_original = pd.read_pickle('instagram_posts.pkl')

# %% [markdown]
# # Testes
#
# ### Podem ser apagados e reescritos

# %% [markdown]
# - Buscando dados e salvando localmente

# %%
os.environ['INSTAGRAM_SCRAPPER_API_TOKEN']="6f36805577msh5e42867c3bd4692p12525ajsn80e3751c2d32"
usernamesList = [
        "altenburg.oficial",
        "altenburghaus",
        "artelasse",
        "artex",
        "buddemeyeroficial",
        "casaalmeidaoficial",
        "casariachuelo",
        "casa.sonno",
        "hoomybr",
        "karstenoficial",
        "mmartanoficial",
        "santistadecora",
        "trussardioficial",
        "trousseauoficial",
        "zeloloja"
    ]

# %%
# userInfos = data_manager.fetch_accounts_infos(usernamesList)
from commom.instagram_data.instagram_data_manager import InstagramAccountInfo
import datetime

userInfos = [InstagramAccountInfo(name='Bem dormir, bem viver', username='altenburg.oficial', followerCount=273937, totalMedia=3509, lastUpdate=pd.to_datetime('2025-01-02'), biography='Moda Casa com elegância, alta qualidade, tecnologias e práticas cada vez mais sustentáveis para o seu bem-estar.', profilePic='https://scontent-atl3-1.cdninstagram.com/v/t51.2885-19/405204100_311861495005263_4564322676966450610_n.jpg?stp=dst-jpg_s640x640_tt6&_nc_ht=scontent-atl3-1.cdninstagram.com&_nc_cat=103&_nc_ohc=66KloZLlbfYQ7kNvgFedCAC&_nc_gid=589f310bf17f4ebbb20d302c1015dcbd&edm=AO4kU9EBAAAA&ccb=7-5&oh=00_AYC6ECndYogLXMAUiS6ZExX3tQbTXprOfXCL-_8hJByzbQ&oe=677C9996&_nc_sid=164c1d'),
 InstagramAccountInfo(name='Altenburg Haus', username='altenburghaus', followerCount=26980, totalMedia=667, lastUpdate=pd.to_datetime('2025-01-02'), biography='Desde 1922, trazendo elegância e sofisticação atemporais para sua casa.', profilePic='https://scontent-hou1-1.cdninstagram.com/v/t51.2885-19/262576167_1531601293888325_7082004465475942676_n.jpg?stp=dst-jpg_s640x640_tt6&_nc_ht=scontent-hou1-1.cdninstagram.com&_nc_cat=105&_nc_ohc=A1TYV1SRL04Q7kNvgETdRIt&_nc_gid=3440eff29a284770ae00723d7ff6eb50&edm=AO4kU9EBAAAA&ccb=7-5&oh=00_AYDtzgzTgpQRIF0sC0bPKgkF1SqahpVhxBFcqqXtzt4ztw&oe=677C943C&_nc_sid=164c1d'),
# [InstagramAccountInfo(name='Bem dormir, bem viver', username='altenburg.oficial', followerCount=273937, totalMedia=3509, lastUpdate=Timestamp('2025-01-02 00:00:00'), biography='Moda Casa com elegância, alta qualidade, tecnologias e práticas cada vez mais sustentáveis para o seu bem-estar.', profilePic='https://scontent-atl3-1.cdninstagram.com/v/t51.2885-19/405204100_311861495005263_4564322676966450610_n.jpg?stp=dst-jpg_s640x640_tt6&_nc_ht=scontent-atl3-1.cdninstagram.com&_nc_cat=103&_nc_ohc=66KloZLlbfYQ7kNvgFedCAC&_nc_gid=589f310bf17f4ebbb20d302c1015dcbd&edm=AO4kU9EBAAAA&ccb=7-5&oh=00_AYC6ECndYogLXMAUiS6ZExX3tQbTXprOfXCL-_8hJByzbQ&oe=677C9996&_nc_sid=164c1d'),
# ...

# %%
df_original = data_handler.read_from_bigquery(query=QUERY_INSTAGRAM_MONITOR)
df_original
# Out:
#                       name           username  followerCount  totalMedia  \
# 0                     Zelo           zeloloja       245610.0      2995.0
# 1                     Zelo           zeloloja       245461.0      2995.0
# 2                     Zelo           zeloloja       244969.0      2994.0
# 3                     Zelo           zeloloja       244657.0      2994.0
# 4                     Zelo           zeloloja       244275.0      2992.0
# ..                     ...                ...            ...         ...
# 235  Bem dormir, bem viver  altenburg.oficial       257898.0      3418.0
# 236  Bem dormir, bem viver  altenburg.oficial       257642.0      3416.0
# 237  Bem dormir, bem viver  altenburg.oficial       257642.0      3416.0
# 238  Bem dormir, bem viver  altenburg.oficial       257642.0      3416.0
# 239  Bem dormir, bem viver  altenburg.oficial       257544.0      3414.0
#
#                           lastUpdate  \
# 0   2024-12-09 09:01:15.004617+00:00
# ...

# %%
new_dataset = data_manager.update_accounts_history_dataset(dataset=df_original,account_info_list=userInfos)
new_dataset
# Out:
# /Users/administrador/Desktop/ammo/innovation-api/src/commom/instagram_data/instagram_data_manager.py:72: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   df_empty = pd.concat([df_empty, df_account_info])
#                   name          username  followerCount  totalMedia  \
# 0                 Zelo          zeloloja       245610.0      2995.0
# 1                 Zelo          zeloloja       245461.0      2995.0
# 2                 Zelo          zeloloja       244969.0      2994.0
# 3                 Zelo          zeloloja       244657.0      2994.0
# 4                 Zelo          zeloloja       244275.0      2992.0
# ..                 ...               ...            ...         ...
# ...

# %% [markdown]
# # Salvando base

# %%
# Usuários
data_manager.data_handler.write_to_bigquery(dataset_id='innovation_dataset', table_id='instagram_accounts_history', dataframe=new_dataset)

# Posts
# data_manager.data_handler.write_to_bigquery(dataset_id='innovation_dataset', table_id='instagram_posts', dataframe=df)

# Local
# pickle.dump(df, open('df_original_2.pkl', "wb"))
# Out:
# [INNOVATION-LOG] [write_to_bigquery] [Line (41)] [INFO]: Connection to BigQuery successful
# [INNOVATION-LOG] [write_to_bigquery] [Line (51)] [INFO]: write done
#                   name          username  followerCount  totalMedia  \
# 0                 Zelo          zeloloja       245610.0      2995.0
# 1                 Zelo          zeloloja       245461.0      2995.0
# 2                 Zelo          zeloloja       244969.0      2994.0
# 3                 Zelo          zeloloja       244657.0      2994.0
# 4                 Zelo          zeloloja       244275.0      2992.0
# ..                 ...               ...            ...         ...
# 250            mmartan    mmartanoficial      1175508.0      4683.0
# 251           Santista    santistadecora      1395748.0      4443.0
# 252          Trussardi  trussardioficial       310669.0       733.0
# 253  Trousseau Oficial  trousseauoficial       259460.0      3923.0
# ...
